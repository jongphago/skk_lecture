# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
from vision_web_app.images.pts import (
    # ca_camera_7_homography as H,
    ca_camera_7_pers_pts,
    ca_camera_7_top_pts,
)

# %%
ca_camera_7_pers_pts = [
    (134, 989),
    (1427, 1205),
    (1661, 1265),
    (1380, 840),
    (1224, 732),
    (627, 720),
    (477, 756),
    (107, 892),
]
ca_camera_7_top_pts = [
    (1593, 635),
    (1260, 364),
    (1227, 383),
    (1046, 881),
    (964, 1377),
    (1321, 1513),
    (1468, 1296),
    (1632, 873),
]
# cam_path = "vision_web_app/images/ca_camera_7_pers.png"
cam_path = "vision_web_app/images/_ca_camera_7_pers.png"
map_path = "vision_web_app/images/ca_camera_7_top.png"

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5))
ax[0].imshow(cv2.cvtColor(cv2.imread(cam_path), cv2.COLOR_BGR2RGB))
ax[1].imshow(cv2.cvtColor(cv2.imread(map_path), cv2.COLOR_BGR2RGB))
plt.show()

# %%
cam_image = cv2.imread(cam_path)
cam_image = cv2.cvtColor(cam_image, cv2.COLOR_BGR2RGB)
cam_image = cv2.polylines(
    cam_image, [np.array(ca_camera_7_pers_pts)], True, (255, 0, 0), 2
)

# %%
map_image = cv2.imread(map_path)
map_image = cv2.cvtColor(map_image, cv2.COLOR_BGR2RGB)
map_image = cv2.polylines(
    map_image, [np.array(ca_camera_7_top_pts)], True, (255, 0, 0), 2
)

# %%
H, _ = cv2.findHomography(
    np.array(ca_camera_7_pers_pts),
    np.array(ca_camera_7_top_pts),
)

# %%
h, w = cam_image.shape[:2]  # 변환할 이미지의 너비와 높이 추출
warped_image = cv2.warpPerspective(
    cam_image, np.array(H), (w, h)
)  # frame에 homography 적용

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 10))
axes[0].imshow(cam_image)
axes[1].imshow(map_image)
axes[2].imshow(warped_image)
plt.show()

# %%
new_map_image = cv2.imread("vision_web_app/images/ca_camera_7_top.png")
h, w, _ = new_map_image.shape
ch, cw = int(h / 2), int(w / 2)
cropped = new_map_image[ch - 750 : ch + 750, cw - 1000 : cw + 1000, :]
resized = cv2.resize(cropped, (640, 480))
cv2.imwrite("vision_web_app/images/_ca_camera_7_top.png", resized)
plt.imshow(cv2.cvtColor(resized, cv2.COLOR_BGR2RGB))
plt.show()

# %%
new_map_image = cv2.resize(new_map_image, (1920, 1440))
plt.imshow(cv2.cvtColor(new_map_image, cv2.COLOR_BGR2RGB))
cv2.imwrite("vision_web_app/images/_ca_mapera_7_pers.png", new_map_image)
